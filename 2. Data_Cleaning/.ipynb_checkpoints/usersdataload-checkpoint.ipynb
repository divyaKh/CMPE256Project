# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy
import json

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
users= []
path = '/content/drive/MyDrive/CMPE256/Data/yelp_academic_dataset_user.json'

# %% [markdown]
# ###Loading user data from Yelp Dataset

# %%
with open(path, encoding = 'utf-8') as fin:
    i = 0 
    for line in fin:
        line_contents = json.loads(line)
        users.append(line_contents)

# %%
data_user = pd.DataFrame(users)
data_user.shape
# Out:
# (1987897, 22)

# %%
data_user.head(5)
# Out:
#                   user_id    name  review_count        yelping_since  useful  \
# 0  qVc8ODYU5SZjKXVBgXdI7w  Walker           585  2007-01-25 16:47:26    7217
# 1  j14WgRoU_-2ZE1aw1dXrJg  Daniel          4333  2009-01-25 04:35:42   43091
# 2  2WnXYQFK0hXEoTxPtV2zvg   Steph           665  2008-07-25 10:41:00    2086
# 3  SZDeASXq7o05mMNLshsdIA    Gwen           224  2005-11-29 04:38:33     512
# 4  hA5lMy-EnncsH4JoR-hFGQ   Karen            79  2007-01-05 19:40:59      29
#
#    funny   cool                                              elite  \
# 0   1259   5994                                               2007
# 1  13066  27281  2009,2010,2011,2012,2013,2014,2015,2016,2017,2...
# 2   1010   1003                           2009,2010,2011,2012,2013
# 3    330    299                                     2009,2010,2011
# 4     15      7
#
#                                              friends  fans  ...  \
# 0  NSCy54eWehBJyZdG2iE84w, pe42u7DcCH2QmI81NX-8qA...   267  ...
# ...

# %% [markdown]
# #### Writing coverted user data to CSV format

# %%
data_user.to_csv("users_CA.csv")

# %%
data_user.columns
# Out:
# Index(['user_id', 'name', 'review_count', 'yelping_since', 'useful', 'funny',
#        'cool', 'elite', 'friends', 'fans', 'average_stars', 'compliment_hot',
#        'compliment_more', 'compliment_profile', 'compliment_cute',
#        'compliment_list', 'compliment_note', 'compliment_plain',
#        'compliment_cool', 'compliment_funny', 'compliment_writer',
#        'compliment_photos'],
#       dtype='object')

# %% [markdown]
# #### Reading the California Specific User Reviews

# %%
data_review = pd.read_csv('/content/drive/MyDrive/CMPE256/Data/CSVfiles/California_reviews_c.csv',index_col = 0)
data_review.head()
# Out:
#                 review_id                 user_id             business_id  \
# 0  pUycOfUwM8vqX7KjRRhUEA  59MxRhNVhU9MYndMkz0wtw  gebiRewfieSdtt17PTW6Zg
# 1  eCiWBf1CJ0Zdv1uVarEhhw  OhECKhQEexFypOMY6kypRw  vC2qm1y3Au5czBtbhc-DNw
# 2  YbMyvlDA2W3Py5lTz8VK-A  4hBhtCSgoxkrFgHa4YAD-w  bbEXAEFr4RYHLlZ-HFssTA
# 3  L0jv8c2FbpWSlfNC6bbUEA  bFPdtzu11Oi0f92EAcjqmg  IDtLPgUrqorrpqSLdfMhZQ
# 4  4zopEEPqfwm-c_FNpeHZYw  JYYYKt6TdVA4ng9lLcXt_g  SZU9c8V2GuREDN5KgyHFJw
#
#    stars  useful  funny  cool  \
# 0    3.0       0      0     0
# 1    4.0       0      0     0
# 2    5.0       0      0     0
# 3    5.0       0      0     0
# 4    5.0       0      0     0
#
#                                                 text                 date  \
# 0  Had a party of 6 here for hibachi. Our waitres...  2016-07-25 07:31:06
# 1  Yes, this is the only sushi place in town. How...  2013-09-04 03:48:20
# 2  Great burgers,fries and salad!  Burgers have a...  2017-01-02 03:17:34
# ...

# %%
data_review = data_review.drop(columns=['text'])

# %% [markdown]
# #### Extracting unique California user ids

# %%
unique_CA_users = pd.DataFrame({'user_id': data_review.user_id.unique()})
unique_CA_users.head(5)
# Out:
#                   user_id
# 0  59MxRhNVhU9MYndMkz0wtw
# 1  OhECKhQEexFypOMY6kypRw
# 2  4hBhtCSgoxkrFgHa4YAD-w
# 3  bFPdtzu11Oi0f92EAcjqmg
# 4  JYYYKt6TdVA4ng9lLcXt_g

# %% [markdown]
# #### Merging CA unique user ids with Yelp user data

# %%
d2 = data_user
intersected_df = d2.merge(unique_CA_users, how='left', on=['user_id'], indicator=True)
intersected_df.head(5)
# Out:
#                   user_id    name  review_count        yelping_since  useful  \
# 0  qVc8ODYU5SZjKXVBgXdI7w  Walker           585  2007-01-25 16:47:26    7217
# 1  j14WgRoU_-2ZE1aw1dXrJg  Daniel          4333  2009-01-25 04:35:42   43091
# 2  2WnXYQFK0hXEoTxPtV2zvg   Steph           665  2008-07-25 10:41:00    2086
# 3  SZDeASXq7o05mMNLshsdIA    Gwen           224  2005-11-29 04:38:33     512
# 4  hA5lMy-EnncsH4JoR-hFGQ   Karen            79  2007-01-05 19:40:59      29
#
#    funny   cool                                              elite  \
# 0   1259   5994                                               2007
# 1  13066  27281  2009,2010,2011,2012,2013,2014,2015,2016,2017,2...
# 2   1010   1003                           2009,2010,2011,2012,2013
# 3    330    299                                     2009,2010,2011
# 4     15      7
#
#                                              friends  fans  ...  \
# 0  NSCy54eWehBJyZdG2iE84w, pe42u7DcCH2QmI81NX-8qA...   267  ...
# ...

# %%
user_df = intersected_df.loc[intersected_df['_merge'] == 'both']
user_df.shape
# Out:
# (115258, 23)

# %%
user_df = user_df.replace(r'^\s*$', np.nan, regex=True)
user_df
# Out:
#                         user_id       name  review_count        yelping_since  \
# 0        qVc8ODYU5SZjKXVBgXdI7w     Walker           585  2007-01-25 16:47:26
# 3        SZDeASXq7o05mMNLshsdIA       Gwen           224  2005-11-29 04:38:33
# 5        q_QQ5kBBwlCcbL1s4NVK3g       Jane          1221  2005-03-14 20:26:35
# 10       iYzhPPqnrjJkg1JHZyMhzA      Chris             4  2010-11-03 18:59:20
# 18       QF1Kuhs8iwLWANNZxebTow  Catherine           607  2009-04-27 20:25:54
# ...                         ...        ...           ...                  ...
# 1987867  Y4QbfsRktpJr2eygVRqe7w      Janet             6  2015-06-20 03:44:00
# 1987868  Ml7Yh0WhJVZapqZ19Fsr2g      Kelli             2  2017-04-22 22:37:56
# 1987869  xzt22UaBjy40CHgCjJ3Fgg        Don             7  2009-05-19 20:42:33
# 1987874  Pt3u_iZV4Lo--4yfYsBhGg     Jordan             5  2013-07-13 23:58:30
# 1987896  wL5jPrLRVCK_Pmo4lM1zpA        Isa             2  2020-12-19 02:32:39
#
#          useful  funny   cool  \
# ...

# %%
user_df.isnull().sum()
# Out:
# user_id                    0
# name                       0
# review_count               0
# yelping_since              0
# useful                     0
# funny                      0
# cool                       0
# elite                 103649
# friends                    0
# fans                       0
# average_stars              0
# compliment_hot             0
# compliment_more            0
# compliment_profile         0
# compliment_cute            0
# compliment_list            0
# compliment_note            0
# compliment_plain           0
# compliment_cool            0
# compliment_funny           0
# compliment_writer          0
# compliment_photos          0
# _merge                     0
# dtype: int64

# %% [markdown]
# #### Creating Is_elite column for users

# %%
user_df['is_elite'] = ~np.array(user_df.elite.isnull())
user_df.is_elite.describe()
# Out:
# count     115258
# unique         2
# top        False
# freq      103649
# Name: is_elite, dtype: object

# %% [markdown]
# #### Adding User's Joining year in Yelp

# %%
# get the year
user_joining_year = [eval(x.split('-')[0]) for x in user_df.yelping_since]
user_df['year'] = user_joining_year
user_df = user_df.drop(columns=['_merge'])

# %% [markdown]
# #### Exporting final user data to CSV format

# %%
user_df.to_csv("/content/drive/MyDrive/CMPE256/Data/CSVfiles/CA_users_c.csv")
