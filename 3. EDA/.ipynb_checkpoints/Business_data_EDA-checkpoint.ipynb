# %% [markdown]
# # Exploratory Data Analysis (EDA) on the business dataset from Yelp
#
# #### This analysis would generate summary statistics for the various numerical data in the dataset, present various important features of the dataset and their meaning and also create various graphical representations to understand the business dataset better

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# !pip install scikit-surprise
# !pip install fuzzywuzzy

# %%
# library imports

import seaborn as sns 
import pandas as pd
import matplotlib.pyplot as plt
import json,os
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
from collections import Counter
import fuzzywuzzy
from fuzzywuzzy import process
import nltk
from nltk.corpus import stopwords
from nltk import sent_tokenize, word_tokenize
import warnings
warnings.filterwarnings('ignore')
import re

import matplotlib.pyplot as plt
import seaborn as sns 
import matplotlib.gridspec as gridspec 

# graph viz
import plotly.offline as pyo

from plotly.graph_objs import *
import plotly.graph_objs as go

#map section
import imageio
import folium
import folium.plugins as plugins


# import chardet

# from nltk.tokenize import RegexpTokenizer
# from stop_words import get_stop_words
# from wordcloud import WordCloud, STOPWORDS
#viz
# Out:
# /Users/archie/opt/anaconda3/lib/python3.9/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %% [markdown]
# ### Reading the raw json business dataset file and displaying the structure :

# %%
# business_path = '/content/drive/MyDrive/CMPE256/Data/yelp_academic_dataset_business.json'
business_path = '../Raw_json_files/yelp_academic_dataset_business.json'

# %%
business = pd.read_json(business_path, lines=True)

# %%
print("\n================================Display of the raw business data of Yelp dataset===========================\n")
business.head()
# Out:
# ================================Display of the raw business data of Yelp dataset===========================
#               business_id                      name  \
# 0  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2  tUFrWirKiKi_TAnsVWINQQ                    Target
# 3  MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4  mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
#
#                            address           city state postal_code  \
# 0           1616 Chapala St, Ste 2  Santa Barbara    CA       93101
# 1  87 Grasso Plaza Shopping Center         Affton    MO       63123
# 2             5255 E Broadway Blvd         Tucson    AZ       85711
# 3                      935 Race St   Philadelphia    PA       19107
# 4                    101 Walnut St     Green Lane    PA       18054
#
#     latitude   longitude  stars  review_count  is_open  \
# 0  34.426679 -119.711197    5.0             7        0
# 1  38.551126  -90.335695    3.0            15        1
# 2  32.223236 -110.880452    3.5            22        0
# 3  39.955505  -75.155564    4.0            80        1
# 4  40.338183  -75.471659    4.5            13        1
#
#                                           attributes  \
# 0                      {'ByAppointmentOnly': 'True'}
# 1             {'BusinessAcceptsCreditCards': 'True'}
# 2  {'BikeParking': 'True', 'BusinessAcceptsCredit...
# 3  {'RestaurantsDelivery': 'False', 'OutdoorSeati...
# 4  {'BusinessAcceptsCreditCards': 'True', 'Wheelc...
#
#                                           categories  \
# 0  Doctors, Traditional Chinese Medicine, Naturop...
# 1  Shipping Centers, Local Services, Notaries, Ma...
# 2  Department Stores, Shopping, Fashion, Home & G...
# 3  Restaurants, Food, Bubble Tea, Coffee & Tea, B...
# 4                          Brewpubs, Breweries, Food
#
#                                                hours
# 0                                               None
# 1  {'Monday': '0:0-0:0', 'Tuesday': '8:0-18:30', ...
# 2  {'Monday': '8:0-22:0', 'Tuesday': '8:0-22:0', ...
# 3  {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', ...
# 4  {'Wednesday': '14:0-22:0', 'Thursday': '16:0-2...

# %%
print("\n============================Display of the columns in business data of Yelp dataset=======================\n")
business.columns
# Out:
# ============================Display of the columns in business data of Yelp dataset=======================
# Index(['business_id', 'name', 'address', 'city', 'state', 'postal_code',
#        'latitude', 'longitude', 'stars', 'review_count', 'is_open',
#        'attributes', 'categories', 'hours'],
#       dtype='object')

# %% [markdown]
# ### Display of Yelp business data distribution on the map:

# %%
# !pip install -q condacolab
# import condacolab
# condacolab.install()

# %%
# !conda install -c conda-forge basemap-data-hires --yes

# %%
# !apt-get install -q libgeos-3.5.0
# !apt-get install -q libgeos-dev
# !pip install -q https://github.com/matplotlib/basemap/archive/master.zip

# %%
# !pip install -q pyproj==1.9.6

# %%
# !pip install Basemap

# %%
# !pip install matplotlib==3.1.3
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#imports for Basemap
import os
# !conda install basemap
# !conda install mpl_toolkits.basemap
# !conda install -c conda-forge basemap-data-hires --yes
os.environ['PROJ_LIB'] = 'C:/Users/shouv/Anaconda3/Lib/site-packages/mpl_toolkits/basemap'
from mpl_toolkits.basemap import Basemap

# used to fix a n error conda install -c conda-forge basemap-data-hires --yes

# %%
# Reducing it down to only the North American region 
long_min, long_max = -132.714844, -59.589844
lat_min, lat_max = 13.976715,56.395664

index_NA = (business["longitude"]>long_min) &\
            (business["longitude"]<long_max) &\
            (business["latitude"]>lat_min) &\
            (business["latitude"]<lat_max)
#apply the selector to subset
NA_business_yelp=business[index_NA ]

# %%
#figure initialization
plt.figure(figsize=(12,6))
m2 = Basemap(projection='merc',
             llcrnrlat=lat_min,
             urcrnrlat=lat_max,
             llcrnrlon=long_min,
             urcrnrlon=long_max,
             lat_ts=35,
            )

m2.fillcontinents(color='#191919',lake_color='lightBlue') 
m2.drawmapboundary(fill_color='lightBlue')                
m2.drawcountries(linewidth=0.5, color="w")              # thin white line for country borders

# Plotting the data
mxy = m2(NA_business_yelp["longitude"].tolist(), NA_business_yelp["latitude"].tolist())
m2.scatter(mxy[0], mxy[1], s=5, c="red", lw=0, alpha=0.05, zorder=5)

plt.title("North American Region Distribution of Yelp Business dataset")
plt.savefig('./images/business_distribution.png')

# %% [markdown]
# ### Evaluating the different features and checking on null values or duplicate entries:

# %%
print("\nDisplay of the column 'categories' no of null rows : ", business.categories.isnull().sum())

#filling the null values with " " empty string
business.categories = business.categories.fillna(" ")
# Out:
# Display of the column 'categories' no of null rows :  103

# %%
#Checking whether there are any duplicate entries
business.business_id.describe()
# Out:
# count                     150346
# unique                    150346
# top       Pns2l4eNsfO8kk83dixA6A
# freq                           1
# Name: business_id, dtype: object

# %% [markdown]
# ####  Hence, there are no duplicate entries as there are no recurring business ids

# %% [markdown]
# ### Displaying the various businesses present in the Yelp Dataset and their respective count:

# %%
complete_business = business.assign(categories = business.categories.str.split(', ')).explode('categories')
category = complete_business.categories.value_counts()
category = category.to_frame().reset_index()
category.columns = ['Categories', 'Count']
print("\n============================Displaying the different business categories present on Yelp=======================\n")
category
# Out:
# ============================Displaying the different business categories present on Yelp=======================
#                 Categories  Count
# 0              Restaurants  52268
# 1                     Food  27781
# 2                 Shopping  24395
# 3            Home Services  14356
# 4            Beauty & Spas  14292
# ...                    ...    ...
# 1307            Patent Law      1
# 1308                Hainan      1
# 1309  Housing Cooperatives      1
# 1310             Guamanian      1
# 1311           Trade Fairs      1
#
# [1312 rows x 2 columns]

# %% [markdown]
# #### We can see that there are a total of 1311 categories of various different businesses.

# %% [markdown]
# ### Displaying the top 10 businesses in the Yelp dataset:

# %%
category= category.sort_values(by = 'Count', ascending = False)

# %%
category = category[0:10]
objects = list(category.Categories)
y_pos = np.arange(len(objects))
Numbers = list(category.Count)

fig = plt.figure(figsize=(20,10))
plt.bar(y_pos, Numbers, align='center', alpha=1)
plt.xticks(y_pos, objects)
plt.ylabel('Number of Occurences')
plt.title('Top 10 Business Categories in Yelp dataset')
plt.savefig('./images/top_10_business_categories.png')

# %% [markdown]
# #### We could infer that most of the data is based on the Restaurant and Food business therefore this dataset would be a good pick to recommend restaurants to various users. We would also now filter out  'Restaurant' or 'Food' in their categories column and store it in a dataframe as we narrow down towards the required datafram for our Restaurant recommendation system.

# %% [markdown]
# ### Extracting now only the Restaurant and Food businesses from Yelp dataset:

# %%
# creating a dataframe to store all the records which has 'Restaurants' or 'Food' in their categories column 
restaurant_dataframe = pd.DataFrame()
for i in business.index:
    if 'Restaurants' in business.categories[i] or 'Food' in business.categories[i]:
        restaurant_dataframe =restaurant_dataframe.append(business.iloc[i])

# %%
restaurant_dataframe = restaurant_dataframe.reset_index(drop=True)
restaurant_dataframe.info()
restaurant_dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64616 entries, 0 to 64615
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   business_id   64616 non-null  object
#  1   name          64616 non-null  object
#  2   address       64616 non-null  object
#  3   city          64616 non-null  object
#  4   state         64616 non-null  object
#  5   postal_code   64616 non-null  object
#  6   latitude      64616 non-null  float64
#  7   longitude     64616 non-null  float64
#  8   stars         64616 non-null  float64
#  9   review_count  64616 non-null  int64
#  10  is_open       64616 non-null  int64
#  11  attributes    63740 non-null  object
#  12  categories    64616 non-null  object
#  13  hours         55281 non-null  object
# dtypes: float64(3), int64(2), object(9)
# memory usage: 6.9+ MB
#                   business_id                           name  \
# 0      MTSW4McQd7CbVtyjqoe9mw             St Honore Pastries
# 1      mWMc6_wTdE0EUBKIGXDVfA       Perkiomen Valley Brewery
# 2      CF33F8-E6oudUQ46HnavjQ                 Sonic Drive-In
# 3      k0hlBqXX-Bt0vf1op7Jr1w          Tsevi's Pub And Grill
# 4      bBDDEgkFA1Otx9Lfe7BZUQ                 Sonic Drive-In
# ...                       ...                            ...
# 64611  cM6V90ExQD6KMSU3rRB5ZA              Dutch Bros Coffee
# 64612  1jx1sfgjgVg0nM6n3p0xWA           Savaya Coffee Market
# 64613  WnT9NIzQgLlILjPT0kEcsQ  Adelita Taqueria & Restaurant
# 64614  2O2K6SXPWv56amqxCECd4w                   The Plum Pit
# 64615  hn9Toz3s-Ei3uZPt7esExA          West Side Kebab House
#
#                      address          city state postal_code   latitude  \
# 0                935 Race St  Philadelphia    PA       19107  39.955505
# 1              101 Walnut St    Green Lane    PA       18054  40.338183
# 2              615 S Main St  Ashland City    TN       37015  36.269593
# 3          8025 Mackenzie Rd        Affton    MO       63123  38.565165
# 4        2312 Dickerson Pike     Nashville    TN       37207  36.208102
# ...                      ...           ...   ...         ...        ...
# 64611    1181 N Milwaukee St         Boise    ID       83704  43.615401
# 64612      11177 N Oracle Rd    Oro Valley    AZ       85737  32.409552
# 64613          1108 S 9th St  Philadelphia    PA       19147  39.935982
# 64614        4405 Pennell Rd         Aston    DE       19014  39.856185
# 64615  2470 Guardian Road NW      Edmonton    AB     T5T 1K8  53.509649
#
#         longitude  stars  review_count  is_open  \
# 0      -75.155564    4.0            80        1
# 1      -75.471659    4.5            13        1
# 2      -87.058943    2.0             6        1
# 3      -90.321087    3.0            19        0
# 4      -86.768170    1.5            10        1
# ...           ...    ...           ...      ...
# 64611 -116.284689    4.0            33        1
# 64612 -110.943073    4.5            41        1
# 64613  -75.158665    4.5            35        1
# 64614  -75.427725    4.5            14        1
# 64615 -113.675999    4.5            18        0
#
#                                               attributes  \
# 0      {'RestaurantsDelivery': 'False', 'OutdoorSeati...
# 1      {'BusinessAcceptsCreditCards': 'True', 'Wheelc...
# 2      {'BusinessParking': 'None', 'BusinessAcceptsCr...
# 3      {'Caters': 'True', 'Alcohol': 'u'full_bar'', '...
# 4      {'RestaurantsAttire': ''casual'', 'Restaurants...
# ...                                                  ...
# 64611  {'WiFi': ''free'', 'RestaurantsGoodForGroups':...
# 64612  {'BusinessParking': '{'garage': False, 'street...
# 64613  {'WheelchairAccessible': 'False', 'Restaurants...
# 64614  {'RestaurantsDelivery': 'False', 'BusinessAcce...
# 64615  {'Ambience': '{'touristy': False, 'hipster': F...
#
#                                               categories  \
# 0      Restaurants, Food, Bubble Tea, Coffee & Tea, B...
# 1                              Brewpubs, Breweries, Food
# 2      Burgers, Fast Food, Sandwiches, Food, Ice Crea...
# 3      Pubs, Restaurants, Italian, Bars, American (Tr...
# 4      Ice Cream & Frozen Yogurt, Fast Food, Burgers,...
# ...                                                  ...
# 64611  Cafes, Juice Bars & Smoothies, Coffee & Tea, R...
# 64612  Specialty Food, Food, Coffee & Tea, Coffee Roa...
# 64613                               Restaurants, Mexican
# 64614  Restaurants, Comfort Food, Food, Food Trucks, ...
# 64615                        Middle Eastern, Restaurants
#
#                                                    hours
# 0      {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', ...
# 1      {'Wednesday': '14:0-22:0', 'Thursday': '16:0-2...
# 2      {'Monday': '0:0-0:0', 'Tuesday': '6:0-22:0', '...
# 3                                                   None
# 4      {'Monday': '0:0-0:0', 'Tuesday': '6:0-21:0', '...
# ...                                                  ...
# 64611  {'Monday': '0:0-0:0', 'Tuesday': '0:0-17:0', '...
# 64612  {'Monday': '0:0-0:0', 'Tuesday': '6:0-14:0', '...
# 64613  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...
# 64614  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...
# 64615  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...
#
# [64616 rows x 14 columns]

# %%
# display of the attributes column of the restaurant datadframe created
restaurant_dataframe['attributes'][0]
# Out:
# {'RestaurantsDelivery': 'False',
#  'OutdoorSeating': 'False',
#  'BusinessAcceptsCreditCards': 'False',
#  'BusinessParking': "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  'BikeParking': 'True',
#  'RestaurantsPriceRange2': '1',
#  'RestaurantsTakeOut': 'True',
#  'ByAppointmentOnly': 'False',
#  'WiFi': "u'free'",
#  'Alcohol': "u'none'",
#  'Caters': 'True'}

# %%
# Taking into the consideration the restaurant businesses which are open
# 1 = open, 0 = closed
restaurant_dataframe = restaurant_dataframe[restaurant_dataframe['is_open']==1]

# %%
# Considering US states only

states = pd.Series(["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DC", "DE", "FL", "GA", 
          "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", 
          "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", 
          "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC", 
          "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY"])

# %% [markdown]
# ### Graphical display of average rating stars given to the Restaurants across each state in US:

# %%
avg_stars = pd.pivot_table(restaurant_dataframe[restaurant_dataframe['state'].isin(states)] , index = ['state'], 
                    values = ['stars'], aggfunc = np.mean)

avg_stars=avg_stars.sort_values('stars',ascending=False)

fig = plt.figure(figsize=(25,10))
ax = fig.add_subplot(111)
a = sns.barplot(x=avg_stars.index, y="stars", data=avg_stars)
plt.title('Average rating of restaurants in US')
plt.savefig('./images/average_rating_of_US_states.png')

# %% [markdown]
# ### Distribution of restaurants state-wise in the dataframe:

# %%
state_count = restaurant_dataframe.state.value_counts()

state_count = state_count.to_frame().reset_index()
state_count.columns = ['State', 'Counts']

objects = list(state_count.State)
y_pos = np.arange(len(objects))
Numbers = list(state_count.Counts)

fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111)
plt.bar(y_pos, Numbers, align='center', alpha=1)
plt.xticks(y_pos, objects)
plt.ylabel('Number of Occurences')
plt.title('Distribution of Restaurant data/occurrences state-wise in US')
plt.savefig('./images/state-wise_restaurant_distribution_in_US.png')

# %% [markdown]
# #### From this, graph, we could statewise distribution of restaurants. As we can see, this data consists of restaurants present all over, fornour analysis we would take the restaurants in California.

# %% [markdown]
# ### Analysis of restaurants in California state only:

# %%
business_in_CA = restaurant_dataframe[restaurant_dataframe.state == 'CA']
business_in_CA = business_in_CA.reset_index(drop = True)
print("\n============================Display of the restaurant businesses in California only=======================\n")
business_in_CA.head()
# Out:
# ============================Display of the restaurant businesses in California only=======================
#               business_id                             name  \
# 0  IDtLPgUrqorrpqSLdfMhZQ             Helena Avenue Bakery
# 1  SZU9c8V2GuREDN5KgyHFJw  Santa Barbara Shellfish Company
# 2  ifjluUv4VASwmFqEp8cWlQ                    Marty's Pizza
# 3  VeFfrEZ4iWaecrQg6Eq4cg                         Cal Taco
# 4  bdfZdB2MTXlT6-RBjSIpQg                       Pho Bistro
#
#                      address           city state postal_code   latitude  \
# 0      131 Anacapa St, Ste C  Santa Barbara    CA       93101  34.414445
# 1          230 Stearns Wharf  Santa Barbara    CA       93101  34.408715
# 2         2733 De La Vina St  Santa Barbara    CA       93105  34.436236
# 3  7320 Hollister Ave, Ste 1         Goleta    CA       93117  34.430542
# 4  903 Embarcadero Del Norte     Isla Vista    CA       93117  34.412934
#
#     longitude  stars  review_count  is_open  \
# 0 -119.690672    4.0           389        1
# 1 -119.685019    4.0          2404        1
# 2 -119.726147    4.0            64        1
# 3 -119.882367    4.0           189        1
# 4 -119.855531    3.0           184        1
#
#                                           attributes  \
# 0  {'RestaurantsTakeOut': 'True', 'NoiseLevel': '...
# 1  {'OutdoorSeating': 'True', 'RestaurantsAttire'...
# 2  {'Alcohol': 'u'none'', 'BusinessAcceptsCreditC...
# 3  {'RestaurantsGoodForGroups': 'True', 'Business...
# 4  {'RestaurantsDelivery': 'True', 'BikeParking':...
#
#                                           categories  \
# 0  Food, Restaurants, Salad, Coffee & Tea, Breakf...
# 1  Live/Raw Food, Restaurants, Seafood, Beer Bar,...
# 2                                 Pizza, Restaurants
# 3  Burgers, Cafes, Restaurants, Mexican, American...
# 4  Food, Restaurants, Chinese, Bubble Tea, Vietna...
#
#                                                hours
# 0  {'Monday': '0:0-0:0', 'Tuesday': '8:0-14:0', '...
# 1  {'Monday': '0:0-0:0', 'Tuesday': '11:0-21:0', ...
# 2  {'Tuesday': '11:0-21:30', 'Wednesday': '11:0-2...
# 3  {'Monday': '0:0-0:0', 'Tuesday': '8:0-20:30', ...
# 4  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...

# %%
# type(business_in_CA.attributes[1])
# dict

# %% [markdown]
# ### The 'attributes' column here contains features which we can use to make the recommendations more suitable therefore this column is further spread out into difffrent attribute columns:

# %%
def find_superset_of_column_names(data):
    column_names = set()
    
    for line_contents in data:
        column_names.update(
                set(find_column_names(line_contents))
                )
    return column_names

def find_column_names(line_contents):
    column_names = []
    if line_contents is None:
        return ''
    for k in line_contents.keys():
        column_names.append('{0}'.format(k)
        )
    
    return column_names

# %%
superset_cols = find_superset_of_column_names(business_in_CA.attributes)

# put all those columns in the dataset and initilize them to nan
for col in superset_cols:
    business_in_CA[col]= np.nan

idx = 0
for attr in business_in_CA.attributes:
    if attr is None:
        idx+=1
        continue
    for k,v in attr.items():
        if'{' in v:
            continue
        business_in_CA[k][idx] = v
    idx+=1

# %%
null_val = pd.DataFrame(business_in_CA.isna().sum())
print("Null values: ",null_val)
print("Shape of original data", business_in_CA.shape)
business_in_CA.info()
# Out:
# Null values:                                0
# business_id                   0
# name                          0
# address                       0
# city                          0
# state                         0
# postal_code                   0
# latitude                      0
# longitude                     0
# stars                         0
# review_count                  0
# is_open                       0
# attributes                   13
# categories                    0
# hours                        75
# WiFi                        317
# AcceptsInsurance            985
# Caters                      278
# OutdoorSeating              333
# ByAppointmentOnly           791
# RestaurantsCounterService   984
# BusinessAcceptsCreditCards   69
# NoiseLevel                  446
# DogsAllowed                 602
# Smoking                     908
# RestaurantsTableService     630
# Corkage                     857
# RestaurantsDelivery         207
# Alcohol                     406
# Music                       986
# RestaurantsPriceRange2      166
# BusinessAcceptsBitcoin      771
# RestaurantsGoodForGroups    457
# DietaryRestrictions         986
# GoodForDancing              922
# HasTV                       408
# RestaurantsReservations     416
# WheelchairAccessible        562
# BestNights                  986
# BYOBCorkage                 934
# BusinessParking             971
# CoatCheck                   900
# RestaurantsAttire           496
# Ambience                    982
# RestaurantsTakeOut          129
# HappyHour                   696
# GoodForMeal                 983
# Open24Hours                 985
# GoodForKids                 400
# AgesAllowed                 984
# DriveThru                   843
# BikeParking                 187
# BYOB                        857
# Shape of original data (986, 52)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 986 entries, 0 to 985
# Data columns (total 52 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   business_id                 986 non-null    object
#  1   name                        986 non-null    object
#  2   address                     986 non-null    object
#  3   city                        986 non-null    object
#  4   state                       986 non-null    object
#  5   postal_code                 986 non-null    object
#  6   latitude                    986 non-null    float64
#  7   longitude                   986 non-null    float64
#  8   stars                       986 non-null    float64
#  9   review_count                986 non-null    int64
#  10  is_open                     986 non-null    int64
#  11  attributes                  973 non-null    object
#  12  categories                  986 non-null    object
#  13  hours                       911 non-null    object
#  14  WiFi                        669 non-null    object
#  15  AcceptsInsurance            1 non-null      object
#  16  Caters                      708 non-null    object
#  17  OutdoorSeating              653 non-null    object
#  18  ByAppointmentOnly           195 non-null    object
#  19  RestaurantsCounterService   2 non-null      object
#  20  BusinessAcceptsCreditCards  917 non-null    object
#  21  NoiseLevel                  540 non-null    object
#  22  DogsAllowed                 384 non-null    object
#  23  Smoking                     78 non-null     object
#  24  RestaurantsTableService     356 non-null    object
#  25  Corkage                     129 non-null    object
#  26  RestaurantsDelivery         779 non-null    object
#  27  Alcohol                     580 non-null    object
#  28  Music                       0 non-null      float64
#  29  RestaurantsPriceRange2      820 non-null    object
#  30  BusinessAcceptsBitcoin      215 non-null    object
#  31  RestaurantsGoodForGroups    529 non-null    object
#  32  DietaryRestrictions         0 non-null      float64
#  33  GoodForDancing              64 non-null     object
#  34  HasTV                       578 non-null    object
#  35  RestaurantsReservations     570 non-null    object
#  36  WheelchairAccessible        424 non-null    object
#  37  BestNights                  0 non-null      float64
#  38  BYOBCorkage                 52 non-null     object
#  39  BusinessParking             15 non-null     object
#  40  CoatCheck                   86 non-null     object
#  41  RestaurantsAttire           490 non-null    object
#  42  Ambience                    4 non-null      object
#  43  RestaurantsTakeOut          857 non-null    object
#  44  HappyHour                   290 non-null    object
#  45  GoodForMeal                 3 non-null      object
#  46  Open24Hours                 1 non-null      object
#  47  GoodForKids                 586 non-null    object
#  48  AgesAllowed                 2 non-null      object
#  49  DriveThru                   143 non-null    object
#  50  BikeParking                 799 non-null    object
#  51  BYOB                        129 non-null    object
# dtypes: float64(6), int64(2), object(44)
# memory usage: 400.7+ KB

# %% [markdown]
# ### Dropping the columns with maximum number of null values:

# %%
col_del = list(null_val[null_val.iloc[:,0] >300].index)# columns to keep
col_del

business_in_CA.drop(columns=col_del).isna().sum()
business_in_CA = business_in_CA.drop(columns=col_del)
business_in_CA
# Out:
#                 business_id                             name  \
# 0    IDtLPgUrqorrpqSLdfMhZQ             Helena Avenue Bakery
# 1    SZU9c8V2GuREDN5KgyHFJw  Santa Barbara Shellfish Company
# 2    ifjluUv4VASwmFqEp8cWlQ                    Marty's Pizza
# 3    VeFfrEZ4iWaecrQg6Eq4cg                         Cal Taco
# 4    bdfZdB2MTXlT6-RBjSIpQg                       Pho Bistro
# ..                      ...                              ...
# 981  2xxkaRy7rP5EUyjFt2J5kA                      Nikka Ramen
# 982  8IV78gQwTH-eZgbfFS_plg                Lost & Found Cafe
# 983  IRBhPAC4ZoDpXazpoB3epQ          Good Stuff Baked Treats
# 984  Bo-GGwQNcLVwyKeYkbfAYg                      Vino Divino
# 985  8BUr8GviR2o_b-brO21wwQ                Kyle's Isla Vista
#
#                        address           city state postal_code   latitude  \
# 0        131 Anacapa St, Ste C  Santa Barbara    CA       93101  34.414445
# 1            230 Stearns Wharf  Santa Barbara    CA       93101  34.408715
# 2           2733 De La Vina St  Santa Barbara    CA       93105  34.436236
# 3    7320 Hollister Ave, Ste 1         Goleta    CA       93117  34.430542
# 4    903 Embarcadero Del Norte     Isla Vista    CA       93117  34.412934
# ..                         ...            ...   ...         ...        ...
# 981            5701 Calle Real         Goleta    CA       93117  34.440885
# 982             919 Linden Ave    Carpinteria    CA       93013  34.398568
# 983                             Santa Barbara    CA       93101  34.420334
# 984         2012 De La Vina St  Santa Barbara    CA       93105  34.429154
# 985    900 Embarcadero Del Mar     Isla Vista    CA       93117  34.412966
#
#       longitude  stars  review_count  is_open  \
# 0   -119.690672    4.0           389        1
# 1   -119.685019    4.0          2404        1
# 2   -119.726147    4.0            64        1
# 3   -119.882367    4.0           189        1
# 4   -119.855531    3.0           184        1
# ..          ...    ...           ...      ...
# 981 -119.823523    4.5           562        1
# 982 -119.519034    5.0             5        1
# 983 -119.710749    5.0             9        1
# 984 -119.717222    5.0            19        1
# 985 -119.856886    2.5            12        1
#
#                                             attributes  \
# 0    {'RestaurantsTakeOut': 'True', 'NoiseLevel': '...
# 1    {'OutdoorSeating': 'True', 'RestaurantsAttire'...
# 2    {'Alcohol': 'u'none'', 'BusinessAcceptsCreditC...
# 3    {'RestaurantsGoodForGroups': 'True', 'Business...
# 4    {'RestaurantsDelivery': 'True', 'BikeParking':...
# ..                                                 ...
# 981  {'ByAppointmentOnly': 'False', 'Alcohol': 'u'b...
# 982                                               None
# 983  {'BikeParking': 'False', 'RestaurantsPriceRang...
# 984  {'BusinessParking': '{'garage': False, 'street...
# 985  {'OutdoorSeating': 'True', 'BusinessAcceptsBit...
#
#                                             categories  \
# 0    Food, Restaurants, Salad, Coffee & Tea, Breakf...
# 1    Live/Raw Food, Restaurants, Seafood, Beer Bar,...
# 2                                   Pizza, Restaurants
# 3    Burgers, Cafes, Restaurants, Mexican, American...
# 4    Food, Restaurants, Chinese, Bubble Tea, Vietna...
# ..                                                 ...
# 981                       Restaurants, Japanese, Ramen
# 982  Home Decor, Home & Garden, Coffee & Tea, Food,...
# 983  Food, Food Delivery Services, Bakeries, Desser...
# 984  Event Planning & Services, Wine Tasting Room, ...
# 985  Restaurants, Burgers, Food, Ice Cream & Frozen...
#
#                                                  hours Caters  \
# 0    {'Monday': '0:0-0:0', 'Tuesday': '8:0-14:0', '...   True
# 1    {'Monday': '0:0-0:0', 'Tuesday': '11:0-21:0', ...  False
# 2    {'Tuesday': '11:0-21:30', 'Wednesday': '11:0-2...    NaN
# 3    {'Monday': '0:0-0:0', 'Tuesday': '8:0-20:30', ...   True
# 4    {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...  False
# ..                                                 ...    ...
# 981  {'Tuesday': '17:0-21:30', 'Wednesday': '17:0-2...  False
# 982                                               None    NaN
# 983  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...   True
# 984  {'Monday': '0:0-0:0', 'Tuesday': '12:0-18:0', ...  False
# 985                                               None   True
#
#     BusinessAcceptsCreditCards RestaurantsDelivery RestaurantsPriceRange2  \
# 0                         True                None                      2
# 1                         True                True                      2
# 2                         True                True                      2
# 3                         True                True                      1
# 4                         True                True                      1
# ..                         ...                 ...                    ...
# 981                       True                True                      2
# 982                        NaN                 NaN                    NaN
# 983                       True                True                      2
# 984                       True               False                      2
# 985                       True                True                    NaN
#
#     RestaurantsTakeOut BikeParking
# 0                 True        True
# 1                 True        True
# 2                 True         NaN
# 3                 True        True
# 4                 True        True
# ..                 ...         ...
# 981               True        True
# 982                NaN         NaN
# 983               True       False
# 984              False        True
# 985               True        True
#
# [986 rows x 20 columns]

# %% [markdown]
# ### Splitting the contents in 'category' attribute

# %%
business_in_CA.shape
# Out:
# (986, 20)

# %%
category_elements = []
for i in business_in_CA.index:
    elements = business_in_CA.categories[i].split(',')
    for element in elements:
        category_elements.append(element)

# %%
category_elements = [x.strip(' ') for x in category_elements]
category_elements
# Out:
# ['Food',
#  'Restaurants',
#  'Salad',
#  'Coffee & Tea',
#  'Breakfast & Brunch',
#  'Sandwiches',
#  'Bakeries',
#  'Live/Raw Food',
#  'Restaurants',
#  'Seafood',
#  'Beer Bar',
#  'Beer',
#  'Wine & Spirits',
#  'Bars',
#  'Food',
#  'Nightlife',
#  'Pizza',
#  'Restaurants',
#  'Burgers',
#  'Cafes',
#  'Restaurants',
#  'Mexican',
#  'American (Traditional)',
#  'Food',
#  'Restaurants',
#  'Chinese',
#  'Bubble Tea',
#  'Vietnamese',
#  'Chicken Wings',
#  'Salad',
#  'Restaurants',
#  'Pizza',
#  'Italian',
#  'Sandwiches',
#  'Coffee & Tea',
#  'Coffee Roasteries',
#  'Food',
#  'Restaurants',
#  'Thai',
#  'Beer',
#  'Wine & Spirits',
#  'Pubs',
#  'Arts & Entertainment',
#  'Kombucha',
#  'Nightlife',
#  'Wineries',
#  'Food',
#  'Bars',
#  'Beer Bar',
#  'Themed Cafes',
#  'Cafes',
#  'Pets',
#  'Arts & Entertainment',
#  "Women's Clothing",
#  'Coffee & Tea',
#  'Shopping',
#  'Pet Adoption',
#  'Fashion',
#  'Pet Sitting',
#  'Accessories',
#  'Pet Stores',
#  'Pet Services',
#  'Food',
#  'Restaurants',
#  'Food',
#  'Food Delivery Services',
#  'Burgers',
#  'Pizza',
#  'Caterers',
#  'Event Planning & Services',
#  'Restaurants',
#  'Food',
#  'Health & Medical',
#  'Juice Bars & Smoothies',
#  'Wineries',
#  'Food',
#  'Restaurants',
#  'Arts & Entertainment',
#  'Festivals',
#  'Food Stands',
#  'Breweries',
#  'Shopping',
#  'Food Court',
#  'Food',
#  'Venues & Event Spaces',
#  'Restaurants',
#  'Event Planning & Services',
#  'Wineries',
#  'Wine Tasting Room',
#  'Arts & Entertainment',
#  'Shopping Centers',
#  'Breweries',
#  'Brewpubs',
#  'Food',
#  'Convenience Stores',
#  'Gas Stations',
#  'Food',
#  'Automotive',
#  'Chinese',
#  'Restaurants',
#  'Asian Fusion',
#  'Szechuan',
#  'Food',
#  'Food Trucks',
#  'Food',
#  'Vietnamese',
#  'Restaurants',
#  'Bubble Tea',
#  'Sandwiches',
#  'Restaurants',
#  'Salad',
#  'Hot Dogs',
#  'Delis',
#  'Food',
#  'Breweries',
#  'Sandwiches',
#  'Specialty Food',
#  'Food',
#  'Health Markets',
#  'Juice Bars & Smoothies',
#  'Restaurants',
#  'Restaurants',
#  'Fast Food',
#  'Chinese',
#  'American (Traditional)',
#  'Vegetarian',
#  'Restaurants',
#  'Wine Bars',
#  'Beer',
#  'Wine & Spirits',
#  'Nightlife',
#  'Bars',
#  'Arts & Entertainment',
#  'Wineries',
#  'Food',
#  'Thai',
#  'Restaurants',
#  'Restaurants',
#  'Soup',
#  'Salad',
#  'Thai',
#  'Grocery',
#  'Fashion',
#  'Department Stores',
#  'Shopping',
#  'Food',
#  'Wholesale Stores',
#  'Fast Food',
#  'Burgers',
#  'Restaurants',
#  'American (Traditional)',
#  'Restaurants',
#  'Seafood',
#  'Burgers',
#  'Tacos',
#  'Sandwiches',
#  'Mexican',
#  'Bars',
#  'Food',
#  'Beer Bar',
#  'Juice Bars & Smoothies',
#  'Nightlife',
#  'Bars',
#  'Burgers',
#  'Restaurants',
#  'Nightlife',
#  'Sports Bars',
#  'American (New)',
#  'Mexican',
#  'Restaurants',
#  'Food Trucks',
#  'Food',
#  'Mexican',
#  'Arts & Entertainment',
#  'Festivals',
#  'Restaurants',
#  'Religious Organizations',
#  'Churches',
#  'Restaurants',
#  'Fast Food',
#  'Mexican',
#  'Tacos',
#  'Burgers',
#  'Breakfast & Brunch',
#  'Restaurants',
#  'Sushi Bars',
#  'Restaurants',
#  'American (Traditional)',
#  'Food Delivery Services',
#  'Caterers',
#  'Venues & Event Spaces',
#  'Cocktail Bars',
#  'Bars',
#  'Wedding Planning',
#  'Nightlife',
#  'Food',
#  'Event Planning & Services',
#  'Sushi Bars',
#  'Caterers',
#  'Food',
#  'Fast Food',
#  'Event Planning & Services',
#  'Japanese',
#  'Food Delivery Services',
#  'Korean',
#  'Restaurants',
#  'Specialty Food',
#  'Asian Fusion',
#  'Food',
#  'Caterers',
#  'Event Planning & Services',
#  'Ice Cream & Frozen Yogurt',
#  'Shaved Ice',
#  'Desserts',
#  'Grocery',
#  'Drugstores',
#  'Pharmacy',
#  'Shopping',
#  'Food',
#  'Health & Medical',
#  'Mexican',
#  'Restaurants',
#  'Breakfast & Brunch',
#  'American (Traditional)',
#  'Vegan',
#  'Restaurants',
#  'Tapas Bars',
#  'Nightlife',
#  'Salad',
#  'Restaurants',
#  'Cocktail Bars',
#  'Bars',
#  'Wine Bars',
#  'Cafes',
#  'Pizza',
#  'American (New)',
#  'Seafood',
#  'Venues & Event Spaces',
#  'Cocktail Bars',
#  'Restaurants',
#  'Nightlife',
#  'Breakfast & Brunch',
#  'American (Traditional)',
#  'Event Planning & Services',
#  'Bars',
#  'American (New)',
#  'Desserts',
#  'Bakeries',
#  'Cupcakes',
#  'Food',
#  'Breweries',
#  'Nightlife',
#  'Food',
#  'Cocktail Bars',
#  'Bars',
#  'Restaurants',
#  'Brewpubs',
#  'Gastropubs',
#  'Food',
#  'Vegetarian',
#  'Salad',
#  'Restaurants',
#  'Cafes',
#  'American (Traditional)',
#  'Burgers',
#  'Juice Bars & Smoothies',
#  'Restaurants',
#  'Fast Food',
#  'Burgers',
#  'Restaurants',
#  'Asian Fusion',
#  'Seafood',
#  'Sushi Bars',
#  'Japanese',
#  'American (Traditional)',
#  'Restaurants',
#  'Bars',
#  'Nightlife',
#  'Mexican',
#  'Tacos',
#  'Restaurants',
#  'Restaurants',
#  'American (Traditional)',
#  'Nightlife',
#  'Bars',
#  'Cocktail Bars',
#  'Food',
#  'Farmers Market',
#  'Specialty Food',
#  'Fruits & Veggies',
#  'Mexican',
#  'Restaurants',
#  'Bakeries',
#  'Food',
#  'Sandwiches',
#  'Coffee & Tea',
#  'Japanese',
#  'Restaurants',
#  'Asian Fusion',
#  'Fast Food',
#  'Sushi Bars',
#  'Japanese',
#  'Restaurants',
#  'Food',
#  'Transportation',
#  'Wineries',
#  'Taxis',
#  'Limos',
#  'Arts & Entertainment',
#  'Hotels & Travel',
#  'Seafood Markets',
#  'Specialty Food',
#  'Food',
#  'Coffee & Tea',
#  'Breakfast & Brunch',
#  'Restaurants',
#  'American (New)',
#  'Food',
#  'Chicken Wings',
#  'Restaurants',
#  'Beer',
#  'Wine & Spirits',
#  'Sandwiches',
#  'Food',
#  'Pizza',
#  'Italian',
#  'Bars',
#  'Venues & Event Spaces',
#  'Event Planning & Services',
#  'Wine Tasting Room',
#  'Arts & Entertainment',
#  'Food',
#  'Wine Bars',
#  'Beer',
#  'Wine & Spirits',
#  'Nightlife',
#  'Wineries',
#  'Mexican',
#  'Restaurants',
#  'Health Markets',
#  'Coffee & Tea',
#  'Ice Cream & Frozen Yogurt',
#  'Restaurants',
#  'Juice Bars & Smoothies',
#  'Breakfast & Brunch',
#  'Food',
#  'American (New)',
#  'Specialty Food',
#  'Restaurants',
#  'Japanese',
#  'Sushi Bars',
#  'Restaurants',
#  'Mexican',
#  'Cooking Schools',
#  'Shopping',
#  'Cooking Classes',
#  'Restaurants',
#  'Caterers',
#  'Education',
#  'Cafes',
#  'Event Planning & Services',
#  'Specialty Schools',
#  'Arts & Crafts',
#  'Event Planning & Services',
#  'Restaurants',
#  'Nightlife',
#  'Caterers',
#  'Italian',
#  'Bars',
#  'American (Traditional)',
#  'Breakfast & Brunch',
#  'Restaurants',
#  'American (New)',
#  'Burgers',
#  'Wedding Planning',
#  'Transportation',
#  'Party Bus Rentals',
#  'Wineries',
#  'Party & Event Planning',
#  'Local Flavor',
#  'Food',
#  'Wine Tours',
#  'Arts & Entertainment',
#  'Tours',
#  'Limos',
#  'Event Planning & Services',
#  'Hotels & Travel',
#  'Coffee & Tea',
#  'Noodles',
#  'Restaurants',
#  'Seafood',
#  'Japanese',
#  'Ramen',
#  'Food',
#  'Asian Fusion',
#  'Poke',
#  'Restaurants',
#  'Food',
#  'American (New)',
#  'Beer',
#  'Wine & Spirits',
#  'Restaurants',
#  'Chinese',
#  'Fast Food',
#  'Restaurants',
#  'Event Planning & Services',
#  'Party & Event Planning',
#  'Food',
#  'Venues & Event Spaces',
#  'Arts & Entertainment',
#  'Social Clubs',
#  'Specialty Food',
#  'Hotels & Travel',
#  'Event Planning & Services',
#  'Cafes',
#  'Restaurants',
#  'Hotels',
#  'Ice Cream & Frozen Yogurt',
#  'Custom Cakes',
#  'Cupcakes',
#  'Food',
#  'Breakfast & Brunch',
#  'Burgers',
#  'American (Traditional)',
#  'American (New)',
#  'Restaurants',
#  'Food',
#  'Custom Cakes',
#  'Bakeries',
#  'Patisserie/Cake Shop',
#  'Restaurants',
#  'Nightlife',
#  'Japanese',
#  'Bars',
#  'Food',
#  'Italian',
#  'Restaurants',
#  'Restaurants',
#  'Chicken Wings',
#  'Chicken Shop',
#  'Fast Food',
#  'Food',
#  'Arts & Entertainment',
#  'Wine Tasting Room',
#  'Wineries',
#  'Nightlife',
#  'Beer Gardens',
#  'Breweries',
#  'Food',
#  'Beer',
#  'Wine & Spirits',
#  'Thai',
#  'Restaurants',
#  'American (New)',
#  'Pop-Up Restaurants',
#  'Asian Fusion',
#  'Automotive',
#  'Smog Check Stations',
#  'Roadside Assistance',
#  'Auto Repair',
#  'Smokehouse',
#  'Food',
#  'Japanese',
#  'Restaurants',
#  'Steakhouses',
#  'Asian Fusion',
#  'Wedding Planning',
#  'Barbeque',
#  'Event Planning & Services',
#  'Restaurants',
#  'Caterers',
#  'Personal Chefs',
#  'Restaurants',
#  'Delis',
#  'Food',
#  'Grocery',
#  'Steakhouses',
#  'Sushi Bars',
#  'Restaurants',
#  'Japanese',
#  'Ice Cream & Frozen Yogurt',
#  'Food',
#  'Juice Bars & Smoothies',
#  'Food',
#  'Restaurants',
#  'Breakfast & Brunch',
#  'American (Traditional)',
#  'Restaurants',
#  'Shopping Centers',
#  'Shopping',
#  'Local Flavor',
#  'Food',
#  'Beer',
#  'Wine & Spirits',
#  'Restaurants',
#  'Barbeque',
#  'Mexican',
#  'Restaurants',
#  'Cafes',
#  'Bagels',
#  'Food',
#  'Restaurants',
#  'Mexican',
#  'Bars',
#  'Restaurants',
#  'Nightlife',
#  'Sandwiches',
#  'American (New)',
#  'Tapas Bars',
#  'Wine Bars',
#  'Restaurants',
#  'American (Traditional)',
#  'Lounges',
#  'Nightlife',
#  'Bars',
#  'Burgers',
#  'American (New)',
#  'Salad',
#  'Sandwiches',
#  'Restaurants',
#  'Pizza',
#  'Hotels & Travel',
#  'Arts & Entertainment',
#  'Beer Tours',
#  'Beer',
#  'Wine & Spirits',
#  'Food',
#  'Festivals',
#  'Tours',
#  'Food',
#  'Beer',
#  'Wine & Spirits',
#  'Restaurants',
#  'Chinese',
#  'Hotels & Travel',
#  'Horseback Riding',
#  'Tours',
#  'Arts & Entertainment',
#  'Wineries',
#  'Wine Tours',
#  'Food',
#  'Active Life',
#  'Restaurants',
#  'Mexican',
#  'Restaurants',
#  'American (Traditional)',
#  'American (New)',
#  'Salad',
#  'Pizza',
#  'Gluten-Free',
#  'Sandwiches',
#  'Restaurants',
#  'American (New)',
#  'Restaurants',
#  'Breakfast & Brunch',
#  'Cafes',
#  'Cajun/Creole',
#  'Bubble Tea',
#  'Restaurants',
#  'Food',
#  'Asian Fusion',
#  'Vegan',
#  'Acai Bowls',
#  'Coffee & Tea',
#  'Fast Food',
#  'Food',
#  'Restaurants',
#  'Burgers',
#  'Food',
#  'Internet Cafes',
#  'Coffee & Tea',
#  'Acai Bowls',
#  'Juice Bars & Smoothies',
#  'Bagels',
#  'Convenience Stores',
#  'Food',
#  'Coffee & Tea',
#  'American (Traditional)',
#  'Restaurants',
#  'Wine Bars',
#  'Pizza',
#  'Cocktail Bars',
#  'Bars',
#  'Vegan',
#  'Nightlife',
#  'Food',
#  'Bubble Tea',
#  'Chinese',
#  'Restaurants',
#  'Asian Fusion',
#  'Hot Pot',
#  'Food',
#  'Tours',
#  'Wine Tours',
#  'Hotels & Travel',
#  'Party & Event Planning',
#  'Event Planning & Services',
#  'Arts & Entertainment',
#  'Local Flavor',
#  'Wineries',
#  'Gas Stations',
#  'Propane',
#  'Local Services',
#  'Convenience Stores',
#  'Food',
#  'Automotive',
#  'Restaurants',
#  'Japanese',
#  'Sushi Bars',
#  'Bubble Tea',
#  'Juice Bars & Smoothies',
#  'Food',
#  'Restaurants',
#  'Mexican',
#  'Fast Food',
#  'Restaurants',
#  'Event Planning & Services',
#  'Hotels',
#  'Hotels & Travel',
#  'Food Trucks',
#  'Food',
#  'Restaurants',
#  'Mexican',
#  'Mexican',
#  'American (Traditional)',
#  'Burgers',
#  'Restaurants',
#  'Pizza',
#  'Restaurants',
#  'Sandwiches',
#  'Salad',
#  'Coffee Roasteries',
#  'Acai Bowls',
#  'Food',
#  'Coffee & Tea',
#  'Sandwiches',
#  'Bagels',
#  'Restaurants',
#  'Cafes',
#  'Shopping',
#  'Health Markets',
#  'Food',
#  'Health & Medical',
#  'Vitamins & Supplements',
#  'Nutritionists',
#  'Specialty Food',
#  'Farmers Market',
#  'American (Traditional)',
#  'American (New)',
#  'Food',
#  'Restaurants',
#  'Restaurants',
#  'Salad',
#  'Pizza',
#  'Chicken Wings',
#  'Bakeries',
#  'Restaurants',
#  'Delis',
#  'Grocery',
#  'Specialty Food',
#  'Health Markets',
#  'Beer',
#  'Wine & Spirits',
#  'Food',
#  'American (New)',
#  'Convenience Stores',
#  'Food',
#  'Beer',
#  'Wine & Spirits',
#  'Food',
#  'Juice Bars & Smoothies',
#  'Restaurants',
#  'Tours',
#  'Wine Tours',
#  'Transportation',
#  'Arts & Entertainment',
#  'Food',
#  'Limos',
#  'Wineries',
#  'Hotels & Travel',
#  'Beer',
#  'Wine & Spirits',
#  'Bars',
#  'Mexican',
#  'Nightlife',
#  'Restaurants',
#  'Local Services',
#  'Food',
#  'Water Purification Services',
#  'Specialty Food',
#  'Health Markets',
#  'Contractors',
#  'Home Services',
#  'Water Delivery',
#  'Plumbing',
#  'Beauty & Spas',
#  'Home & Garden',
#  'Shopping',
#  'Skin Care',
#  'Grocery',
#  'Food',
#  'Salad',
#  'Sandwiches',
#  'Restaurants',
#  'Pizza',
#  'Nightlife',
#  'Arts & Entertainment',
#  'Restaurants',
#  'Dance Clubs',
#  'Bars',
#  'Music Venues',
#  'Mexican',
#  'Sports Bars',
#  'Restaurants',
#  'Asian Fusion',
#  'Food',
#  'Poke',
#  'Hawaiian',
#  'Seafood',
#  'American (Traditional)',
#  'Restaurants',
#  'Bars',
#  'Cocktail Bars',
#  'Nightlife',
#  'American (New)',
#  'Sandwiches',
#  'Coffee & Tea',
#  'Food',
#  'Coffee Roasteries',
#  'Breakfast & Brunch',
#  'Restaurants',
#  'Bakeries',
#  'Food',
#  'Australian',
#  'Restaurants',
#  'Seafood',
#  'American (New)',
#  'Steakhouses',
#  'Comfort Food',
#  'Bubble Tea',
#  'Restaurants',
#  'Tea Rooms',
#  'Asian Fusion',
#  'Coffee & Tea',
#  'Food',
#  'Food',
#  'Burgers',
#  'Restaurants',
#  'Fast Food',
#  'Coffee & Tea',
#  'Restaurants',
#  'Food',
#  'Desserts',
#  'Coffee & Tea',
#  'Restaurants',
#  'Specialty Food',
#  'Beer',
#  'Wine & Spirits',
#  'Food',
#  'Health Markets',
#  'Grocery',
#  'Fruits & Veggies',
#  'Wine Tasting Room',
#  'Wineries',
#  'Arts & Entertainment',
#  'Wine Bars',
#  'Food',
#  'Nightlife',
#  'Bars',
#  'Beer',
#  'Wine & Spirits',
#  'Local Flavor',
#  'Restaurants',
#  'American (New)',
#  'Barbeque',
#  'Food',
#  'Sandwiches',
#  'Wine Bars',
#  'Diners',
#  'Bars',
#  'Specialty Food',
#  'American (Traditional)',
#  'Nightlife',
#  'Tapas/Small Plates',
#  'Restaurants',
#  'Breakfast & Brunch',
#  'Seafood',
#  'American (New)',
#  'Cajun/Creole',
#  'Restaurants',
#  'Breakfast & Brunch',
#  'Mexican',
#  'Tacos',
#  'Restaurants',
#  'Barbeque',
#  'Food Delivery Services',
#  'Food Trucks',
#  'Food',
#  'Event Planning & Services',
#  'Caterers',
#  'Restaurants',
#  'Mexican',
#  'Salad',
#  'Sandwiches',
#  'Restaurants',
#  'Restaurants',
#  'Vegetarian',
#  'Salad',
#  'Coffee & Tea',
#  'Tex-Mex',
#  'American (Traditional)',
#  'Burgers',
#  'Food',
#  'Sandwiches',
#  'Mexican',
#  'Juice Bars & Smoothies',
#  'Ice Cream & Frozen Yogurt',
#  'Food',
#  'Desserts',
#  'Food',
#  'Coffee & Tea',
#  'Pizza',
#  'Nightlife',
#  'Italian',
#  'Bars',
#  'Restaurants',
#  'Wine Bars',
#  'Restaurants',
#  'Coffee & Tea',
#  'Breakfast & Brunch',
#  'Food',
#  'Cafes',
#  'Food Delivery Services',
#  'Event Planning & Services',
#  'Caterers',
#  'Food',
#  'Food',
#  'Convenience Stores',
#  'Coffee & Tea',
#  'Gas Stations',
#  'Grocery',
#  'Automotive',
#  'Beer',
#  'Wine & Spirits',
#  'Pop-Up Restaurants',
#  'Restaurants',
#  'Food',
#  'Donuts',
#  'Lounges',
#  'American (New)',
#  'Burgers',
#  'Cocktail Bars',
#  'Bars',
#  'Sports Bars',
#  'Nightlife',
#  'Restaurants',
#  'Pizza',
#  'Gluten-Free',
#  'Restaurants',
#  'Event Planning & Services',
#  'Caterers',
#  'Comfort Food',
#  'Bakeries',
#  'Food',
#  'Desserts',
#  'Restaurants',
#  'Empanadas',
#  'Argentine',
#  'Restaurants',
#  'Mexican',
#  'Latin American',
#  'Restaurants',
#  'Argentine',
#  'Empanadas',
#  'Food',
#  'Coffee & Tea',
#  'Bubble Tea',
#  'Food',
#  'Health & Medical',
#  'Vitamins & Supplements',
#  'Shopping',
#  'Health Markets',
#  'Food',
#  'Specialty Food',
#  'Japanese',
#  'Restaurants',
#  'Beer',
#  'Wine & Spirits',
#  'Food',
#  'Sushi Bars',
#  'Coffee & Tea',
#  'Restaurants',
#  'Food',
#  'Noodles',
#  'Restaurants',
#  'Gluten-Free',
#  'Creperies',
#  'Chinese',
#  'Asian Fusion',
#  'Food',
#  'Asian Fusion',
#  'Bubble Tea',
#  'Restaurants',
#  'Japanese',
#  'Ice Cream & Frozen Yogurt',
#  'Juice Bars & Smoothies',
#  'Restaurants',
#  'Specialty Food',
#  'Food',
#  'Shopping',
#  'Food',
#  'Drugstores',
#  'Convenience Stores',
#  'Restaurants',
#  'Party & Event Planning',
#  'Specialty Food',
#  'Delis',
#  'Food',
#  'Meat Shops',
#  'Event Planning & Services',
#  'Caterers',
#  'Juice Bars & Smoothies',
#  'Restaurants',
#  'Food',
#  'Restaurants',
#  'Pizza',
#  'Chicken Wings',
#  'Sandwiches',
#  'Food',
#  'Restaurants',
#  'Middle Eastern',
#  'Cafes',
#  'Bakeries',
#  'American (New)',
#  'Food',
#  'Specialty Food',
#  'Restaurants',
#  'Food',
#  'Restaurants',
#  'Bakeries',
#  'Mexican',
#  'Breakfast & Brunch',
#  'Food',
#  'Coffee & Tea',
#  'Restaurants',
#  'Thai',
#  'Restaurants',
#  'Delis',
#  'Restaurants',
#  'Grocery',
#  'American (New)',
#  'Cafes',
#  'Coffee & Tea',
#  'Beer',
#  'Wine & Spirits',
#  'Food',
#  'Cafes',
#  'Burgers',
#  'Sandwiches',
#  'Restaurants',
#  'Wine Tasting Room',
#  'Tasting Classes',
#  'Bars',
#  'Wineries',
#  'Wine Bars',
#  'Tours',
#  'Food',
#  'Education',
#  'Wine Tasting Classes',
#  'Restaurants',
#  'Hotels & Travel',
#  'Nightlife',
#  'Barbeque',
#  'Wine Tours',
#  'Arts & Entertainment',
#  'Restaurants',
#  'American (New)',
#  'Seafood',
#  'Italian',
#  'Pizza',
#  'Pizza',
#  'Restaurants',
#  'Chicken Wings',
#  'Salad',
#  'Sandwiches',
#  'Food',
#  'Cafes',
#  'Bakeries',
#  'Restaurants',
#  'Juice Bars & Smoothies',
#  'Breakfast & Brunch',
#  'Brazilian',
#  'Restaurants',
#  'Food',
#  'Salad',
#  'Acai Bowls',
#  'Active Life',
#  'Restaurants',
#  'Boating',
#  'Shopping',
#  ...]

# %%
# we are taking 20 most common categories
Counter(category_elements).most_common(20)
# Out:
# [('Restaurants', 668),
#  ('Food', 570),
#  ('Nightlife', 153),
#  ('Bars', 142),
#  ('Breakfast & Brunch', 118),
#  ('Coffee & Tea', 114),
#  ('Sandwiches', 114),
#  ('Mexican', 111),
#  ('American (New)', 109),
#  ('Event Planning & Services', 99),
#  ('American (Traditional)', 96),
#  ('Beer', 90),
#  ('Wine & Spirits', 90),
#  ('Arts & Entertainment', 86),
#  ('Specialty Food', 83),
#  ('Shopping', 76),
#  ('Burgers', 71),
#  ('Wineries', 69),
#  ('Grocery', 68),
#  ('Pizza', 67)]

# %%
features = Counter(category_elements).most_common(20)
feature = [x[0] for x in features]

for col in feature:
    business_in_CA[col]= np.nan
for i in feature:
    for index in business_in_CA.index:
        
        if i in business_in_CA.categories[index]:
            business_in_CA[i][index] = 1
        else:
            business_in_CA[i][index] = 0

# %%
(business_in_CA.columns)
# Out:
# Index(['business_id', 'name', 'address', 'city', 'state', 'postal_code',
#        'latitude', 'longitude', 'stars', 'review_count', 'is_open',
#        'attributes', 'categories', 'hours', 'Caters',
#        'BusinessAcceptsCreditCards', 'RestaurantsDelivery',
#        'RestaurantsPriceRange2', 'RestaurantsTakeOut', 'BikeParking',
#        'Restaurants', 'Food', 'Nightlife', 'Bars', 'Breakfast & Brunch',
#        'Coffee & Tea', 'Sandwiches', 'Mexican', 'American (New)',
#        'Event Planning & Services', 'American (Traditional)', 'Beer',
#        'Wine & Spirits', 'Arts & Entertainment', 'Specialty Food', 'Shopping',
#        'Burgers', 'Wineries', 'Grocery', 'Pizza'],
#       dtype='object')

# %%
## Checking for inconsistent city names
cities = business_in_CA['city'].unique()
cities
# Out:
# array(['Santa Barbara', 'Goleta', 'Isla Vista', 'Carpinteria',
#        'Montecito', 'Port Hueneme', 'Summerland', 'Santa  Barbara',
#        'Truckee', 'Santa Maria'], dtype=object)

# %%
## There only city with inconsistent name is Saint Joseph, so we will update that
business_in_CA['city'] = business_in_CA['city'].str.lower()
business_in_CA['city'] = business_in_CA['city'].str.strip()

def replace_matches(df, column, string_to_match, min_ratio = 80):
    strings = df[column].unique()
    matches = fuzzywuzzy.process.extract(string_to_match, strings, 
                                         limit=10, scorer=fuzzywuzzy.fuzz.token_sort_ratio)
    close_matches = [matches[0] for matches in matches if matches[1] >= min_ratio]
    rows_with_matches = df[column].isin(close_matches)
    df.loc[rows_with_matches, column] = string_to_match
    
for city in cities:
    replace_matches(business_in_CA, column='city', string_to_match=city)

business_in_CA['city'].unique()
# Out:
# array(['Santa  Barbara', 'Goleta', 'Isla Vista', 'Carpinteria',
#        'Montecito', 'Port Hueneme', 'Summerland', 'Truckee',
#        'Santa Maria'], dtype=object)

# %%
city_CA = business_in_CA.city.value_counts()
city_CA = city_CA.to_frame().reset_index()
city_CA.columns = ['City', 'Counts']

# %%
### Distribuiton of restaurant business in California
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111)
plt.bar(city_CA.City, city_CA.Counts, align = 'center', alpha = 1)
plt.xlabel("City")
plt.ylabel("Counts")
plt.savefig('./images/California_city_wise_restaurant_counts.png')

# %% [markdown]
# #### From the above graph we could see that are data is very skewed data based on the cities which have the restaurant reviews

# %% [markdown]
# ### Analysing Restaurants in California who got 5-star ratings and their count:

# %%
import json
reviews = []
# path_rev = '/content/drive/MyDrive/CMPE256/Data/yelp_academic_dataset_review.json'
path_rev = '../Raw_json_files/yelp_academic_dataset_review.json'
with open(path_rev,encoding="utf8") as f:
    for line in f:
        reviews.append(json.loads(line))

# %%
reviews = pd.DataFrame(reviews)
business_ratings = pd.merge(business_in_CA, reviews[['review_id', 'business_id', 'stars']], on = 'business_id', how = 'left')
Five_star = business_ratings[business_ratings['stars_y'] == 5.0]
Five_star_rating = Five_star.name.value_counts()
Five_star_rating = Five_star_rating.to_frame().reset_index()
Five_star_rating.columns = ['Restaurant', 'Counts']
Five_star_rating = Five_star_rating.head(10)
Five_star_rating = Five_star_rating.sort_values(['Counts'], ascending = True)
Five_star_rating
# Out:
#                         Restaurant  Counts
# 9                          Bouchon     971
# 8                  Lure Fish House     980
# 7  Santa Barbara Shellfish Company    1022
# 6                    Lilly's Tacos    1109
# 5      McConnell's Fine Ice Creams    1230
# 4      Boathouse at Hendry's Beach    1274
# 3      Brophy Bros - Santa Barbara    1355
# 2                       Mesa Verde    1523
# 1                  Pickles & Swiss    1533
# 0                       Los Agaves    3464

# %%
fig = plt.figure(figsize = (20,10))
ax = fig.add_subplot(111)
plt.barh(Five_star_rating.Restaurant, Five_star_rating.Counts, align = 'center', alpha = 1)
plt.ylabel('Restaurant name')
plt.xlabel('Number of 5 star ratings')
plt.savefig('./images/5Star_ratings_restaurant_distribution_in_California.png')

# %% [markdown]
# #### From the above analysis we could infer that the restaurant Los Agaves got the highest amount of 5-star ratings in California.

# %% [markdown]
# ### Analysing Restaurants in California who got the most reviews:

# %%
ids = business_in_CA.business_id.to_list()
review_CA = reviews[reviews.business_id.isin(ids)]
review_CA = pd.merge(review_CA, business_in_CA[['business_id', 'name']], on = 'business_id', how = 'left')

# %% [markdown]
# #### Top 10 most reviewed restaurants in California:

# %%
top10_most_reviewed = review_CA.name.value_counts()
top10_most_reviewed = top10_most_reviewed.to_frame().reset_index()
top10_most_reviewed = top10_most_reviewed.head(10)
top10_most_reviewed.columns = ['name', 'Counts']
top10_most_reviewed = top10_most_reviewed.sort_values(['Counts'], ascending = True)
fig = plt.figure(figsize = (20,10))
ax = fig.add_subplot(111)
plt.barh(top10_most_reviewed.name, top10_most_reviewed.Counts, align = 'center', alpha = 1)
plt.ylabel('Restaurant name')
plt.xlabel('Top 10 reviewed Restaurants')
plt.savefig('./images/most_reviewed_restaurants_in_CA.png')
